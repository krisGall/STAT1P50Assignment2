# %%
import pandas
import matplotlib.pyplot

data = pandas.read_csv('student.csv')

data = data[['internet', 'grade']]

data2 = data.groupby('internet').mean().reset_index()

print(data2)
# Out:
#    internet      grade
# 0         0  11.026490
# 1         1  12.172691

# %%
# plotting values
display(matplotlib.pyplot.plot(data2['internet'], data2['grade']))
